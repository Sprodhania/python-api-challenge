# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\h\anaconda3\lib\site-packages (0.0.6)
# Requirement already satisfied: kdtree>=0.12 in c:\users\h\anaconda3\lib\site-packages (from citipy) (0.16)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 592

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#url = f"https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={"weather_api_key"}
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"
#units = "metric"
#query url
#query_url = f"{url}appid={weather_api_key}&units={units}&q="
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    # Log the url, record, and set numbers
    #print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds =city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | margaret river
# Processing Record 2 of Set 1 | lyozna
# Processing Record 3 of Set 1 | bethel
# Processing Record 4 of Set 1 | cidreira
# Processing Record 5 of Set 1 | praia da vitoria
# Processing Record 6 of Set 1 | san martin
# Processing Record 7 of Set 1 | longyearbyen
# Processing Record 8 of Set 1 | iqaluit
# Processing Record 9 of Set 1 | udachny
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | kristiansund
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | vorgashor
# Processing Record 15 of Set 1 | lompoc
# Processing Record 16 of Set 1 | solnechnyy
# Processing Record 17 of Set 1 | grytviken
# Processing Record 18 of Set 1 | keflavik
# Processing Record 19 of Set 1 | college
# Processing Record 20 of Set 1 | adamstown
# Processing Record 21 of Set 1 | pindushi
# Processing Record 22 of Set 1 | tharangambadi
# Processing Record 23 of Set 1 | aksu
# Processing Record 24 of Set 1 | agat village
# Processing Record 25 of Set 1 | ilulissat
# Processing Record 26 of Set 1 | carnarvon
# Processing Record 27 of Set 1 | alofi
# Processing Record 28 of Set 1 | lubang
# Processing Record 29 of Set 1 | hemsby
# Processing Record 30 of Set 1 | afaahiti
# Processing Record 31 of Set 1 | cill airne
# Processing Record 32 of Set 1 | hermiston
# Processing Record 33 of Set 1 | robertsport
# Processing Record 34 of Set 1 | port elizabeth
# Processing Record 35 of Set 1 | betio village
# Processing Record 36 of Set 1 | gadzhiyevo
# Processing Record 37 of Set 1 | darwin
# Processing Record 38 of Set 1 | tiksi
# Processing Record 39 of Set 1 | waitangi
# Processing Record 40 of Set 1 | mount pearl
# Processing Record 41 of Set 1 | klyuchi
# Processing Record 42 of Set 1 | utrik
# Processing Record 43 of Set 1 | fortaleza
# Processing Record 44 of Set 1 | bamboo flat
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | kijang
# Processing Record 47 of Set 1 | lebu
# Processing Record 48 of Set 1 | ulsteinvik
# Processing Record 49 of Set 1 | puerto natales
# Processing Record 50 of Set 1 | lihue
# Processing Record 0 of Set 2 | parys
# Processing Record 1 of Set 2 | margate
# Processing Record 2 of Set 2 | kailua-kona
# Processing Record 3 of Set 2 | aberdeen
# Processing Record 4 of Set 2 | kodiak
# Processing Record 5 of Set 2 | teluknaga
# Processing Record 6 of Set 2 | san german
# Processing Record 7 of Set 2 | weno
# Processing Record 8 of Set 2 | blackmans bay
# Processing Record 9 of Set 2 | corpus christi
# Processing Record 10 of Set 2 | sanibel
# Processing Record 11 of Set 2 | tolanaro
# Processing Record 12 of Set 2 | ahau
# City not found. Skipping...
# Processing Record 13 of Set 2 | hithadhoo
# Processing Record 14 of Set 2 | whitehorse
# Processing Record 15 of Set 2 | edinburgh of the seven seas
# Processing Record 16 of Set 2 | nova sintra
# Processing Record 17 of Set 2 | gouyave
# Processing Record 18 of Set 2 | mil'kovo
# Processing Record 19 of Set 2 | vila franca do campo
# Processing Record 20 of Set 2 | poronaysk
# Processing Record 21 of Set 2 | aykhal
# Processing Record 22 of Set 2 | sumbe
# Processing Record 23 of Set 2 | natal
# Processing Record 24 of Set 2 | chokwe
# Processing Record 25 of Set 2 | ola
# Processing Record 26 of Set 2 | enriquillo
# Processing Record 27 of Set 2 | road town
# Processing Record 28 of Set 2 | bowen
# Processing Record 29 of Set 2 | ribeira grande
# Processing Record 30 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 31 of Set 2 | huaidian
# Processing Record 32 of Set 2 | pacific grove
# Processing Record 33 of Set 2 | talnakh
# Processing Record 34 of Set 2 | whyalla stuart
# City not found. Skipping...
# Processing Record 35 of Set 2 | papatowai
# Processing Record 36 of Set 2 | choibalsan
# Processing Record 37 of Set 2 | ouadda
# Processing Record 38 of Set 2 | manokwari
# Processing Record 39 of Set 2 | anadyr
# Processing Record 40 of Set 2 | christchurch
# Processing Record 41 of Set 2 | outjo
# Processing Record 42 of Set 2 | puerto padre
# Processing Record 43 of Set 2 | hobyo
# Processing Record 44 of Set 2 | invercargill
# Processing Record 45 of Set 2 | bilibino
# Processing Record 46 of Set 2 | mount gambier
# Processing Record 47 of Set 2 | ishigaki
# Processing Record 48 of Set 2 | birao
# Processing Record 49 of Set 2 | nuuk
# Processing Record 0 of Set 3 | iskateley
# Processing Record 1 of Set 3 | wailua homesteads
# Processing Record 2 of Set 3 | abepura
# Processing Record 3 of Set 3 | hawaiian paradise park
# Processing Record 4 of Set 3 | nuevo casas grandes
# Processing Record 5 of Set 3 | port lincoln
# Processing Record 6 of Set 3 | hermanus
# Processing Record 7 of Set 3 | chui
# Processing Record 8 of Set 3 | ust-nera
# Processing Record 9 of Set 3 | derzhavinsk
# Processing Record 10 of Set 3 | skelleftea
# Processing Record 11 of Set 3 | petropavlovsk-kamchatsky
# Processing Record 12 of Set 3 | isafjordur
# Processing Record 13 of Set 3 | thompson
# Processing Record 14 of Set 3 | harstad
# Processing Record 15 of Set 3 | ushuaia
# Processing Record 16 of Set 3 | jamestown
# Processing Record 17 of Set 3 | akobo
# Processing Record 18 of Set 3 | chiili
# City not found. Skipping...
# Processing Record 19 of Set 3 | qamdo
# Processing Record 20 of Set 3 | jayapura
# Processing Record 21 of Set 3 | lata
# Processing Record 22 of Set 3 | sitka
# Processing Record 23 of Set 3 | slave lake
# Processing Record 24 of Set 3 | sungailiat
# Processing Record 25 of Set 3 | hadibu
# Processing Record 26 of Set 3 | pangody
# Processing Record 27 of Set 3 | puerto aysen
# Processing Record 28 of Set 3 | opuwo
# Processing Record 29 of Set 3 | amuntai
# Processing Record 30 of Set 3 | oranjestad
# Processing Record 31 of Set 3 | stanley
# Processing Record 32 of Set 3 | atafu village
# Processing Record 33 of Set 3 | balikpapan
# Processing Record 34 of Set 3 | qaqortoq
# Processing Record 35 of Set 3 | klaksvik
# Processing Record 36 of Set 3 | bay harbor
# Processing Record 37 of Set 3 | chipinge
# Processing Record 38 of Set 3 | tsiombe
# Processing Record 39 of Set 3 | port mathurin
# Processing Record 40 of Set 3 | khandyga
# Processing Record 41 of Set 3 | magadan
# Processing Record 42 of Set 3 | tazacorte
# Processing Record 43 of Set 3 | yuzhno-kurilsk
# Processing Record 44 of Set 3 | benoy-yurt
# Processing Record 45 of Set 3 | vadso
# Processing Record 46 of Set 3 | egilsstadir
# Processing Record 47 of Set 3 | puerto ayora
# Processing Record 48 of Set 3 | newman
# Processing Record 49 of Set 3 | satna
# Processing Record 0 of Set 4 | carutapera
# Processing Record 1 of Set 4 | kingston
# Processing Record 2 of Set 4 | vernon
# Processing Record 3 of Set 4 | chonchi
# Processing Record 4 of Set 4 | igrim
# Processing Record 5 of Set 4 | bardai
# Processing Record 6 of Set 4 | acapulco de juarez
# Processing Record 7 of Set 4 | tazovsky
# Processing Record 8 of Set 4 | harrisburg
# Processing Record 9 of Set 4 | albany
# Processing Record 10 of Set 4 | howrah
# Processing Record 11 of Set 4 | hamilton
# Processing Record 12 of Set 4 | minas de marcona
# Processing Record 13 of Set 4 | west island
# Processing Record 14 of Set 4 | port blair
# Processing Record 15 of Set 4 | pisco
# Processing Record 16 of Set 4 | rundu
# Processing Record 17 of Set 4 | san antonio de pale
# Processing Record 18 of Set 4 | enewetak
# Processing Record 19 of Set 4 | ta`u
# Processing Record 20 of Set 4 | alice springs
# Processing Record 21 of Set 4 | dunedin
# Processing Record 22 of Set 4 | ghadamis
# Processing Record 23 of Set 4 | scarborough
# Processing Record 24 of Set 4 | codrington
# Processing Record 25 of Set 4 | shangri-la
# City not found. Skipping...
# Processing Record 26 of Set 4 | al burayqah
# Processing Record 27 of Set 4 | villa gesell
# Processing Record 28 of Set 4 | saldanha
# Processing Record 29 of Set 4 | miri
# Processing Record 30 of Set 4 | chu
# Processing Record 31 of Set 4 | sinop
# Processing Record 32 of Set 4 | rongelap
# Processing Record 33 of Set 4 | constantia
# Processing Record 34 of Set 4 | olonkinbyen
# Processing Record 35 of Set 4 | yuzhno-sukhokumsk
# Processing Record 36 of Set 4 | shingu
# Processing Record 37 of Set 4 | melfort
# Processing Record 38 of Set 4 | sursk
# Processing Record 39 of Set 4 | bonthe
# Processing Record 40 of Set 4 | suluru
# Processing Record 41 of Set 4 | lom sak
# Processing Record 42 of Set 4 | guiuan
# Processing Record 43 of Set 4 | uzgen
# Processing Record 44 of Set 4 | rajura
# Processing Record 45 of Set 4 | kayangel
# Processing Record 46 of Set 4 | port hueneme
# Processing Record 47 of Set 4 | gobabis
# Processing Record 48 of Set 4 | new norfolk
# Processing Record 49 of Set 4 | ulanhot
# Processing Record 0 of Set 5 | santa terezinha
# Processing Record 1 of Set 5 | la'ie
# Processing Record 2 of Set 5 | tomaszow mazowiecki
# Processing Record 3 of Set 5 | nova vicosa
# Processing Record 4 of Set 5 | qarazhal
# Processing Record 5 of Set 5 | playa blanca
# Processing Record 6 of Set 5 | ornskoldsvik
# Processing Record 7 of Set 5 | rokytne
# Processing Record 8 of Set 5 | mejit
# Processing Record 9 of Set 5 | akureyri
# Processing Record 10 of Set 5 | hwange
# Processing Record 11 of Set 5 | prince albert
# Processing Record 12 of Set 5 | likiep
# Processing Record 13 of Set 5 | dahanu
# Processing Record 14 of Set 5 | ambikapur
# Processing Record 15 of Set 5 | chulakkurgan
# Processing Record 16 of Set 5 | belyy yar
# Processing Record 17 of Set 5 | manta
# Processing Record 18 of Set 5 | hailin
# Processing Record 19 of Set 5 | alotau
# Processing Record 20 of Set 5 | lastoursville
# Processing Record 21 of Set 5 | avarua
# Processing Record 22 of Set 5 | rio grande
# Processing Record 23 of Set 5 | touros
# Processing Record 24 of Set 5 | calama
# Processing Record 25 of Set 5 | general villegas
# Processing Record 26 of Set 5 | ljusdal
# Processing Record 27 of Set 5 | sandnessjoen
# Processing Record 28 of Set 5 | buala
# Processing Record 29 of Set 5 | karratha
# Processing Record 30 of Set 5 | nemuro
# Processing Record 31 of Set 5 | lodja
# Processing Record 32 of Set 5 | punta arenas
# Processing Record 33 of Set 5 | verkhnevilyuysk
# Processing Record 34 of Set 5 | cabo san lucas
# Processing Record 35 of Set 5 | east london
# Processing Record 36 of Set 5 | hammerfest
# Processing Record 37 of Set 5 | sinabang
# Processing Record 38 of Set 5 | san antonio del estrecho
# City not found. Skipping...
# Processing Record 39 of Set 5 | buritis
# Processing Record 40 of Set 5 | nabire
# Processing Record 41 of Set 5 | saudarkrokur
# Processing Record 42 of Set 5 | baie-comeau
# Processing Record 43 of Set 5 | satipo
# Processing Record 44 of Set 5 | geraldton
# Processing Record 45 of Set 5 | bodaybo
# Processing Record 46 of Set 5 | tomatlan
# Processing Record 47 of Set 5 | san patricio
# Processing Record 48 of Set 5 | howard springs
# Processing Record 49 of Set 5 | ailuk
# Processing Record 0 of Set 6 | cabedelo
# Processing Record 1 of Set 6 | santo antonio
# Processing Record 2 of Set 6 | beloomut
# Processing Record 3 of Set 6 | envira
# Processing Record 4 of Set 6 | revda
# Processing Record 5 of Set 6 | namibe
# Processing Record 6 of Set 6 | kirensk
# Processing Record 7 of Set 6 | barra de santo antonio
# Processing Record 8 of Set 6 | kerch
# Processing Record 9 of Set 6 | sokcho
# Processing Record 10 of Set 6 | berbera
# Processing Record 11 of Set 6 | mitu
# Processing Record 12 of Set 6 | luderitz
# Processing Record 13 of Set 6 | pandan
# Processing Record 14 of Set 6 | igarka
# Processing Record 15 of Set 6 | tamanrasset
# Processing Record 16 of Set 6 | ulety
# Processing Record 17 of Set 6 | sur
# Processing Record 18 of Set 6 | kalymnos
# Processing Record 19 of Set 6 | manismata
# Processing Record 20 of Set 6 | la bassee
# Processing Record 21 of Set 6 | isla mujeres
# Processing Record 22 of Set 6 | puerto baquerizo moreno
# Processing Record 23 of Set 6 | camana
# Processing Record 24 of Set 6 | hillsborough
# Processing Record 25 of Set 6 | happy valley-goose bay
# Processing Record 26 of Set 6 | labrador city
# Processing Record 27 of Set 6 | juegang
# Processing Record 28 of Set 6 | haiku-pauwela
# Processing Record 29 of Set 6 | vrede
# Processing Record 30 of Set 6 | zamora
# Processing Record 31 of Set 6 | dudinka
# Processing Record 32 of Set 6 | las heras
# Processing Record 33 of Set 6 | marsh harbour
# Processing Record 34 of Set 6 | dawesville
# Processing Record 35 of Set 6 | acarau
# Processing Record 36 of Set 6 | alaghsas
# Processing Record 37 of Set 6 | ciudad lazaro cardenas
# Processing Record 38 of Set 6 | qarah zia' od din
# Processing Record 39 of Set 6 | pointe-noire
# Processing Record 40 of Set 6 | yaren
# Processing Record 41 of Set 6 | luau
# Processing Record 42 of Set 6 | huaicheng
# Processing Record 43 of Set 6 | kemijarvi
# Processing Record 44 of Set 6 | arraial do cabo
# Processing Record 45 of Set 6 | jieshi
# Processing Record 46 of Set 6 | barberton
# Processing Record 47 of Set 6 | shimoda
# Processing Record 48 of Set 6 | changzhi
# Processing Record 49 of Set 6 | yelizovo
# Processing Record 0 of Set 7 | rabo de peixe
# Processing Record 1 of Set 7 | tura
# Processing Record 2 of Set 7 | chifeng
# Processing Record 3 of Set 7 | tanrake village
# City not found. Skipping...
# Processing Record 4 of Set 7 | gastouni
# Processing Record 5 of Set 7 | banda aceh
# Processing Record 6 of Set 7 | laguna
# Processing Record 7 of Set 7 | sao desiderio
# Processing Record 8 of Set 7 | saint-pierre
# Processing Record 9 of Set 7 | beyneu
# Processing Record 10 of Set 7 | kavieng
# Processing Record 11 of Set 7 | berezovyy
# Processing Record 12 of Set 7 | katsuura
# Processing Record 13 of Set 7 | ormara
# Processing Record 14 of Set 7 | tchintabaraden
# Processing Record 15 of Set 7 | santa elena de uairen
# Processing Record 16 of Set 7 | sarankhola
# Processing Record 17 of Set 7 | muzayri'
# City not found. Skipping...
# Processing Record 18 of Set 7 | nioki
# Processing Record 19 of Set 7 | duong dong
# Processing Record 20 of Set 7 | grootfontein
# Processing Record 21 of Set 7 | tapes
# Processing Record 22 of Set 7 | santa maria
# Processing Record 23 of Set 7 | nishinoomote
# Processing Record 24 of Set 7 | luuq
# Processing Record 25 of Set 7 | bargara
# City not found. Skipping...
# Processing Record 26 of Set 7 | alavus
# Processing Record 27 of Set 7 | brookings
# Processing Record 28 of Set 7 | tobelo
# Processing Record 29 of Set 7 | geneina
# Processing Record 30 of Set 7 | ijuw
# City not found. Skipping...
# Processing Record 31 of Set 7 | el calafate
# Processing Record 32 of Set 7 | parsabad
# Processing Record 33 of Set 7 | welzheim
# Processing Record 34 of Set 7 | changli
# Processing Record 35 of Set 7 | gembu
# Processing Record 36 of Set 7 | saipan
# Processing Record 37 of Set 7 | georgetown
# Processing Record 38 of Set 7 | la passe
# Processing Record 39 of Set 7 | betare oya
# Processing Record 40 of Set 7 | cholpon-ata
# Processing Record 41 of Set 7 | yilan
# Processing Record 42 of Set 7 | gizo
# Processing Record 43 of Set 7 | muskegon
# Processing Record 44 of Set 7 | champerico
# Processing Record 45 of Set 7 | tara
# Processing Record 46 of Set 7 | nadym
# Processing Record 47 of Set 7 | san luis de la loma
# Processing Record 48 of Set 7 | walvis bay
# Processing Record 49 of Set 7 | casino
# Processing Record 0 of Set 8 | orizona
# Processing Record 1 of Set 8 | 'ohonua
# City not found. Skipping...
# Processing Record 2 of Set 8 | prado
# Processing Record 3 of Set 8 | fuvahmulah
# City not found. Skipping...
# Processing Record 4 of Set 8 | salalah
# Processing Record 5 of Set 8 | yangor
# City not found. Skipping...
# Processing Record 6 of Set 8 | aasiaat
# Processing Record 7 of Set 8 | kodinsk
# Processing Record 8 of Set 8 | usogorsk
# Processing Record 9 of Set 8 | allapalli
# Processing Record 10 of Set 8 | sabya
# Processing Record 11 of Set 8 | nar'yan-mar
# Processing Record 12 of Set 8 | kindu
# Processing Record 13 of Set 8 | malango
# Processing Record 14 of Set 8 | stung treng
# Processing Record 15 of Set 8 | yichang
# Processing Record 16 of Set 8 | nuku'alofa
# Processing Record 17 of Set 8 | fort mcmurray
# Processing Record 18 of Set 8 | cururupu
# Processing Record 19 of Set 8 | olavarria
# Processing Record 20 of Set 8 | arthur's town
# City not found. Skipping...
# Processing Record 21 of Set 8 | kapuskasing
# Processing Record 22 of Set 8 | mont-dore
# Processing Record 23 of Set 8 | woolgoolga
# Processing Record 24 of Set 8 | laufach
# Processing Record 25 of Set 8 | kasamwa
# Processing Record 26 of Set 8 | espargos
# City not found. Skipping...
# Processing Record 27 of Set 8 | khromtau
# Processing Record 28 of Set 8 | badger
# Processing Record 29 of Set 8 | ar ruways
# Processing Record 30 of Set 8 | bezhetsk
# Processing Record 31 of Set 8 | mukah
# City not found. Skipping...
# Processing Record 32 of Set 8 | san jeronimo
# Processing Record 33 of Set 8 | volksrust
# Processing Record 34 of Set 8 | pokrovsk
# Processing Record 35 of Set 8 | narvik
# Processing Record 36 of Set 8 | bireun
# Processing Record 37 of Set 8 | hechuan
# Processing Record 38 of Set 8 | dapa
# Processing Record 39 of Set 8 | mishelevka
# Processing Record 40 of Set 8 | partenit
# Processing Record 41 of Set 8 | tadine
# Processing Record 42 of Set 8 | polyarnyy
# Processing Record 43 of Set 8 | vila velha
# Processing Record 44 of Set 8 | puerto san carlos
# City not found. Skipping...
# Processing Record 45 of Set 8 | motueka
# Processing Record 46 of Set 8 | paracuru
# Processing Record 47 of Set 8 | panama city beach
# Processing Record 48 of Set 8 | formosa
# Processing Record 49 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 0 of Set 9 | port saint john's
# Processing Record 1 of Set 9 | sabha
# Processing Record 2 of Set 9 | upington
# Processing Record 3 of Set 9 | queenstown
# Processing Record 4 of Set 9 | balaklava
# Processing Record 5 of Set 9 | wewak
# Processing Record 6 of Set 9 | vorkuta
# Processing Record 7 of Set 9 | kalemie
# Processing Record 8 of Set 9 | taoudenni
# Processing Record 9 of Set 9 | shalqar
# Processing Record 10 of Set 9 | ancud
# Processing Record 11 of Set 9 | emerald
# Processing Record 12 of Set 9 | caleta de carquin
# Processing Record 13 of Set 9 | belmonte
# Processing Record 14 of Set 9 | fort bragg
# Processing Record 15 of Set 9 | wanning
# Processing Record 16 of Set 9 | coquimbo
# Processing Record 17 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 18 of Set 9 | mexico
# Processing Record 19 of Set 9 | tranovaho
# City not found. Skipping...
# Processing Record 20 of Set 9 | midvagur
# Processing Record 21 of Set 9 | colorno
# Processing Record 22 of Set 9 | gamay
# Processing Record 23 of Set 9 | papao
# Processing Record 24 of Set 9 | al ghayzah
# Processing Record 25 of Set 9 | sabang
# Processing Record 26 of Set 9 | altamira
# Processing Record 27 of Set 9 | sao joao da barra
# Processing Record 28 of Set 9 | contai
# Processing Record 29 of Set 9 | chihuahua
# Processing Record 30 of Set 9 | kuanda
# Processing Record 31 of Set 9 | sovetskaya gavan'
# Processing Record 32 of Set 9 | bhanpuri
# Processing Record 33 of Set 9 | chibougamau
# Processing Record 34 of Set 9 | santiago papasquiaro
# Processing Record 35 of Set 9 | spinazzola
# Processing Record 36 of Set 9 | mount isa
# Processing Record 37 of Set 9 | soio
# Processing Record 38 of Set 9 | sinan
# Processing Record 39 of Set 9 | sarupathar
# Processing Record 40 of Set 9 | deniliquin
# Processing Record 41 of Set 9 | padang
# Processing Record 42 of Set 9 | guiria
# City not found. Skipping...
# Processing Record 43 of Set 9 | tual
# Processing Record 44 of Set 9 | santa rosa
# Processing Record 45 of Set 9 | mascota
# Processing Record 46 of Set 9 | mili
# Processing Record 47 of Set 9 | punta del este
# Processing Record 48 of Set 9 | cooma
# Processing Record 49 of Set 9 | jinka
# Processing Record 0 of Set 10 | alice
# Processing Record 1 of Set 10 | fauske
# Processing Record 2 of Set 10 | panagar
# Processing Record 3 of Set 10 | valley city
# Processing Record 4 of Set 10 | broken hill
# Processing Record 5 of Set 10 | coahuayana de hidalgo
# Processing Record 6 of Set 10 | yabassi
# Processing Record 7 of Set 10 | pokachi
# Processing Record 8 of Set 10 | ylojarvi
# Processing Record 9 of Set 10 | portland
# Processing Record 10 of Set 10 | iwanai
# Processing Record 11 of Set 10 | armyansk
# Processing Record 12 of Set 10 | sao vicente
# Processing Record 13 of Set 10 | tonekabon
# Processing Record 14 of Set 10 | machico
# Processing Record 15 of Set 10 | hasaki
# Processing Record 16 of Set 10 | kovdor
# Processing Record 17 of Set 10 | tucupita
# Processing Record 18 of Set 10 | ghanzi
# Processing Record 19 of Set 10 | nikol'sk
# Processing Record 20 of Set 10 | salmon arm
# Processing Record 21 of Set 10 | saint-philippe
# Processing Record 22 of Set 10 | cles
# Processing Record 23 of Set 10 | mandalgovi
# Processing Record 24 of Set 10 | porbandar
# Processing Record 25 of Set 10 | baharly
# Processing Record 26 of Set 10 | faya-largeau
# Processing Record 27 of Set 10 | newnham
# Processing Record 28 of Set 10 | gonzaga
# Processing Record 29 of Set 10 | angaur state
# Processing Record 30 of Set 10 | trinity beach
# Processing Record 31 of Set 10 | dhromolaxia
# Processing Record 32 of Set 10 | preobrazheniye
# Processing Record 33 of Set 10 | robore
# Processing Record 34 of Set 10 | ukata
# Processing Record 35 of Set 10 | qapqal
# City not found. Skipping...
# Processing Record 36 of Set 10 | jeddah
# Processing Record 37 of Set 10 | guerrero negro
# Processing Record 38 of Set 10 | shwebo
# Processing Record 39 of Set 10 | at-bashi
# Processing Record 40 of Set 10 | vilyuchinsk
# Processing Record 41 of Set 10 | paraguari
# Processing Record 42 of Set 10 | al qubbah
# Processing Record 43 of Set 10 | petauke
# Processing Record 44 of Set 10 | boguchar
# Processing Record 45 of Set 10 | mahanoro
# Processing Record 46 of Set 10 | palikir - national government center
# Processing Record 47 of Set 10 | rikaze
# Processing Record 48 of Set 10 | petite riviere
# Processing Record 49 of Set 10 | general pinedo
# Processing Record 0 of Set 11 | bougouni
# Processing Record 1 of Set 11 | arklow
# Processing Record 2 of Set 11 | antalaha
# Processing Record 3 of Set 11 | porto novo
# Processing Record 4 of Set 11 | westport
# Processing Record 5 of Set 11 | prince george
# Processing Record 6 of Set 11 | colinas
# Processing Record 7 of Set 11 | alamosa
# Processing Record 8 of Set 11 | argo
# Processing Record 9 of Set 11 | fort st. john
# Processing Record 10 of Set 11 | twon-brass
# Processing Record 11 of Set 11 | krasnokamsk
# Processing Record 12 of Set 11 | broome
# Processing Record 13 of Set 11 | montepuez
# Processing Record 14 of Set 11 | harper
# Processing Record 15 of Set 11 | san ignacio rio muerto
# Processing Record 16 of Set 11 | ponta delgada
# Processing Record 17 of Set 11 | berdigestyakh
# Processing Record 18 of Set 11 | kulia village
# City not found. Skipping...
# Processing Record 19 of Set 11 | kulhudhuffushi
# Processing Record 20 of Set 11 | mezhdurechenskiy
# Processing Record 21 of Set 11 | piti village
# Processing Record 22 of Set 11 | lorengau
# Processing Record 23 of Set 11 | dispur
# Processing Record 24 of Set 11 | port hedland
# Processing Record 25 of Set 11 | basco
# Processing Record 26 of Set 11 | korla
# Processing Record 27 of Set 11 | correntina
# Processing Record 28 of Set 11 | peace river
# Processing Record 29 of Set 11 | carl junction
# Processing Record 30 of Set 11 | samarinda
# Processing Record 31 of Set 11 | bubaque
# Processing Record 32 of Set 11 | aydincik
# Processing Record 33 of Set 11 | el jadid
# Processing Record 34 of Set 11 | limuru
# Processing Record 35 of Set 11 | yagry
# City not found. Skipping...
# Processing Record 36 of Set 11 | luanda
# Processing Record 37 of Set 11 | fortuna
# Processing Record 38 of Set 11 | kampung sungai ara
# Processing Record 39 of Set 11 | mahina
# Processing Record 40 of Set 11 | san francisco de la paz
# Processing Record 41 of Set 11 | hoemul-li
# Processing Record 42 of Set 11 | fomboni
# Processing Record 43 of Set 11 | floro
# Processing Record 44 of Set 11 | yenifakili
# Processing Record 45 of Set 11 | kerikeri
# Processing Record 46 of Set 11 | novodvinsk
# Processing Record 47 of Set 11 | potosi
# Processing Record 48 of Set 11 | troitsko-pechorsk
# Processing Record 49 of Set 11 | nizhneudinsk
# Processing Record 0 of Set 12 | arroyo
# Processing Record 1 of Set 12 | sept-iles
# Processing Record 2 of Set 12 | ulan bator
# Processing Record 3 of Set 12 | north bend
# Processing Record 4 of Set 12 | yankton
# Processing Record 5 of Set 12 | brisas de zicatela
# Processing Record 6 of Set 12 | noumea
# Processing Record 7 of Set 12 | shengli
# Processing Record 8 of Set 12 | tshikapa
# Processing Record 9 of Set 12 | anta
# Processing Record 10 of Set 12 | xiongzhou
# Processing Record 11 of Set 12 | west fargo
# Processing Record 12 of Set 12 | chuhar jamali
# Processing Record 13 of Set 12 | medina
# Processing Record 14 of Set 12 | basoko
# Processing Record 15 of Set 12 | nelson bay
# Processing Record 16 of Set 12 | alzamay
# Processing Record 17 of Set 12 | madison
# Processing Record 18 of Set 12 | sambava
# Processing Record 19 of Set 12 | homer
# Processing Record 20 of Set 12 | amga
# Processing Record 21 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 12 | ambovombe
# Processing Record 23 of Set 12 | kedrovyy
# Processing Record 24 of Set 12 | tukrah
# Processing Record 25 of Set 12 | pesaro
# Processing Record 26 of Set 12 | likasi
# Processing Record 27 of Set 12 | st. john's
# Processing Record 28 of Set 12 | thunder bay
# Processing Record 29 of Set 12 | lakatoro
# Processing Record 30 of Set 12 | sidi akkacha
# Processing Record 31 of Set 12 | zakynthos
# Processing Record 32 of Set 12 | bikenibeu village
# Processing Record 33 of Set 12 | yanchep
# Processing Record 34 of Set 12 | sisimiut
# Processing Record 35 of Set 12 | kharp
# Processing Record 36 of Set 12 | princeville
# Processing Record 37 of Set 12 | severo-yeniseyskiy
# Processing Record 38 of Set 12 | ponoka
# Processing Record 39 of Set 12 | sibu
# Processing Record 40 of Set 12 | cooper's town
# Processing Record 41 of Set 12 | kununurra
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          567
# Lat           567
# Lng           567
# Max Temp      567
# Humidity      567
# Cloudiness    567
# Wind Speed    567
# Country       567
# Date          567
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    margaret river -33.9500  115.0667     54.91        73           9
# 1            lyozna  55.0249   30.7956     40.96        86           1
# 2            bethel  41.3712  -73.4140     49.10        40          44
# 3          cidreira -30.1811  -50.2056     65.64        62           0
# 4  praia da vitoria  38.7333  -27.0667     64.65        77          75
#
#    Wind Speed Country        Date
# 0        7.87      AU  1730070131
# 1        4.97      BY  1730070132
# 2        3.49      US  1730069986
# 3       14.07      BR  1730070055
# 4        8.05      PT  1730070135

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                      City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          margaret river -33.9500  115.0667     54.91        73           9
# 1                  lyozna  55.0249   30.7956     40.96        86           1
# 2                  bethel  41.3712  -73.4140     49.10        40          44
# 3                cidreira -30.1811  -50.2056     65.64        62           0
# 4        praia da vitoria  38.7333  -27.0667     64.65        77          75
#
#          Wind Speed Country        Date
# City_ID
# 0              7.87      AU  1730070131
# 1              4.97      BY  1730070132
# 2              3.49      US  1730069986
# 3             14.07      BR  1730070055
# 4              8.05      PT  1730070135

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
plt.scatter(lats, max_temps, edgecolor="black", linewidth = 1, marker = "o", alpha = 0.8, label = "Cities" )
# Incorporate the other graph properties
plt.title("City Max Latitude Vs. Temperature(%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
humidity = city_data_df["Humidity"]
plt.scatter(lats, humidity, edgecolor="black", linewidth = 1, marker = "o", alpha = 0.8, label = "Cities" )

# Incorporate the other graph properties
plt.title("City Latitude Vs. Humidity(%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
cloudiness  = city_data_df["Cloudiness"]
plt.scatter(lats, cloudiness, edgecolor = "black", alpha = 0.8, marker = "o", label = "Cities", linewidth = 1)
# Incorporate the other graph properties
plt.title("City Latitide vs. Cloudiness(%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
wind_speed = city_data_df["Wind Speed"]
plt.scatter(lats, wind_speed, edgecolor = "black", linewidth = 1, alpha = 0.8, marker = "o", label = "Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed(%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + " x + " + str(round(intercept, 2))
    
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    #plt.title(title)
    #plt.xlabel("Latitude")
    #plt.ylabel("Max Temp")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    print(f"The r-squared is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
Latitude = city_data_df["Lat"]
#northern_hemi_data = pd.DataFrame(city_data_df)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#                      City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1                  lyozna  55.0249  30.7956     40.96        86           1
# 2                  bethel  41.3712 -73.4140     49.10        40          44
# 4        praia da vitoria  38.7333 -27.0667     64.65        77          75
# 6            longyearbyen  78.2186  15.6401     31.84       100          75
# 7                 iqaluit  63.7506 -68.5145     19.13        85          75
#
#          Wind Speed Country        Date
# City_ID
# 1              4.97      BY  1730070132
# 2              3.49      US  1730069986
# 4              8.05      PT  1730070135
# 6              0.00      SJ  1730070137
# 7             12.66      CA  1730070074

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
Latitude = city_data_df["Lat"]
#southern_hemi_data = pd.DataFrame(city_data_df)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           margaret river -33.9500  115.0667     54.91        73           9
# 3                 cidreira -30.1811  -50.2056     65.64        62           0
# 5               san martin -33.0810  -68.4681     77.79        30           0
# 9        port-aux-francais -49.3500   70.2167     36.19        68         100
# 12              bredasdorp -34.5322   20.0403     60.40        86         100
#
#          Wind Speed Country        Date
# City_ID
# 0              7.87      AU  1730070131
# 3             14.07      BR  1730070055
# 5              3.65      AR  1730069918
# 9             28.07      TF  1730070125
# 12            25.55      ZA  1730070144

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

plt.title("Latitude vs Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plot_linear_regression(x_values, y_values, "Latitude vs Max Temp", (6, 30))
# Out:
# The r-squared is: 0.7611014581255906

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

plt.title("Latitude vs Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plot_linear_regression(x_values, y_values, "Latitude vs Max Temp", (-30, 20))
# Out:
# The r-squared is: 0.5501871415612611

# %% [markdown]
# **Discussion about the linear relationship:** About 55% of the variation in the dependent variable (the outcome) can be explained by the independent variable(s) from this linear regression model. This indicates a moderate level of correlation between the predictors and the outcome.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plot_linear_regression(x_values, y_values, "Latitude vs Humidity", (6, 30))
# Out:
# The r-squared is: 0.03463701414443523

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plot_linear_regression(x_values, y_values, "Latitude vs Humidity", (-30, 30))
# Out:
# The r-squared is: 0.06454148834087606

# %% [markdown]
# **Discussion about the linear relationship:** The result bout 6.5% indicates that there is a very weak relationship between the variables.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (6, 30))
# Out:
# The r-squared is: 0.0510829935275597

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (-30, 10))
# Out:
# The r-squared is: 0.0017095226784085969

# %% [markdown]
# **Discussion about the linear relationship:** The extremely low R-squared value explain that there is almost no relationship between the variables.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (4, 20))
# Out:
# The r-squared is: 0.0017676796683297963

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (-50, 20))
# Out:
# The r-squared is: 0.09474524138086328

# %% [markdown]
# **Discussion about the linear relationship:** The result bout 9.4% indicates that there is a very weak relationship between the variables.
