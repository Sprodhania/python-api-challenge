# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %%
pip install citipy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 609

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#url = f"https://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={"weather_api_key"}
url = f"http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID={weather_api_key}"
#units = "metric"
#query url
#query_url = f"{url}appid={weather_api_key}&units={units}&q="
# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval")
print("-" * 15)

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city

    # Log the url, record, and set numbers
    #print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds =city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------
# Processing Record 1 of Set 1 | iqaluit
# Processing Record 2 of Set 1 | edinburgh of the seven seas
# Processing Record 3 of Set 1 | veraval
# Processing Record 4 of Set 1 | port mathurin
# Processing Record 5 of Set 1 | puerto ayora
# Processing Record 6 of Set 1 | tura
# Processing Record 7 of Set 1 | sao vicente
# Processing Record 8 of Set 1 | leh
# Processing Record 9 of Set 1 | namtsy
# Processing Record 10 of Set 1 | susuman
# Processing Record 11 of Set 1 | lihue
# Processing Record 12 of Set 1 | fonte boa
# Processing Record 13 of Set 1 | kirensk
# Processing Record 14 of Set 1 | ribeira grande
# Processing Record 15 of Set 1 | fortuna
# Processing Record 16 of Set 1 | grytviken
# Processing Record 17 of Set 1 | geraldton
# Processing Record 18 of Set 1 | fale old settlement
# Processing Record 19 of Set 1 | port-aux-francais
# Processing Record 20 of Set 1 | aasiaat
# Processing Record 21 of Set 1 | wynne
# ...

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          580
# Lat           580
# Lng           580
# Max Temp      580
# Humidity      580
# Cloudiness    580
# Wind Speed    580
# Country       580
# Date          580
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                           City      Lat      Lng  Max Temp  Humidity  \
# 0                      iqaluit  63.7506 -68.5145     33.53        86
# 1  edinburgh of the seven seas -37.0676 -12.3116     53.44        63
# 2                      veraval  20.9000  70.3667     81.81        83
# 3                port mathurin -19.6833  63.4167     73.22        72
# 4                 puerto ayora  -0.7393 -90.3518     70.56        93
#
#    Cloudiness  Wind Speed Country        Date
# 0         100        5.75      CA  1729027476
# 1           7        9.95      SH  1729027477
# 2          52        8.37      IN  1729027478
# 3          84       15.43      MU  1729027479
# 4          71        8.99      EC  1729027480

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                kuanda  56.3161  116.0806     12.81        85          88
# 1        port elizabeth -33.9180   25.5701     61.32        72          40
# 2              la passe  45.5549   -0.8967     68.02        79          93
# 3              hermanus -34.4187   19.2345     60.80        72           0
# 4                mathba  22.2855   89.9629     76.41        83          10
#
#          Wind Speed Country        Date
# City_ID
# 0              1.59      RU  1729019147
# 1             19.57      ZA  1729019148
# 2              8.68      FR  1729019149
# 3             21.27      ZA  1729019151
# 4              1.74      BD  1729019152

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
plt.scatter(lats, max_temps, edgecolor="black", linewidth = 1, marker = "o", alpha = 0.8, label = "Cities" )
# Incorporate the other graph properties
plt.title("City Max Latitude Vs. Temperature(%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
humidity = city_data_df["Humidity"]
plt.scatter(lats, humidity, edgecolor="black", linewidth = 1, marker = "o", alpha = 0.8, label = "Cities" )

# Incorporate the other graph properties
plt.title("City Latitude Vs. Humidity(%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
cloudiness  = city_data_df["Cloudiness"]
plt.scatter(lats, cloudiness, edgecolor = "black", alpha = 0.8, marker = "o", label = "Cities", linewidth = 1)
# Incorporate the other graph properties
plt.title("City Latitide vs. Cloudiness(%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
wind_speed = city_data_df["Wind Speed"]
plt.scatter(lats, wind_speed, edgecolor = "black", linewidth = 1, alpha = 0.8, marker = "o", label = "Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed(%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def plot_linear_regression(x_values,y_values,title,text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope, 2)) + " x + " + str(round(intercept, 2))
    
    plt.scatter(x_values, y_values)
    plt.plot(x_values, regress_values, "r-")
    #plt.title(title)
    #plt.xlabel("Latitude")
    #plt.ylabel("Max Temp")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    print(f"The r-squared is: {rvalue**2}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
Latitude = city_data_df["Lat"]
#northern_hemi_data = pd.DataFrame(city_data_df)
northern_hemi_df = city_data_df[city_data_df["Lat"] >= 0]
# Display sample data
northern_hemi_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          kuanda  56.3161  116.0806     12.81        85          88
# 2        la passe  45.5549   -0.8967     68.02        79          93
# 4          mathba  22.2855   89.9629     76.41        83          10
# 5           price  39.5994 -110.8107     70.00        30           0
# 8         changji  44.0167   87.3167     52.59        62           0
#
#          Wind Speed Country        Date
# City_ID
# 0              1.59      RU  1729019147
# 2              8.68      FR  1729019149
# 4              1.74      BD  1729019152
# 5              7.16      US  1729019153
# 8              2.24      CN  1729019156

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
Latitude = city_data_df["Lat"]
#southern_hemi_data = pd.DataFrame(city_data_df)
southern_hemi_df = city_data_df[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                                 City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 1                     port elizabeth -33.9180   25.5701     61.32        72
# 3                           hermanus -34.4187   19.2345     60.80        72
# 6                           waitangi -43.9535 -176.5597     44.82        85
# 7        edinburgh of the seven seas -37.0676  -12.3116     53.80        63
# 10                        middelburg -25.7751   29.4648     52.93        76
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 1                40       19.57      ZA  1729019148
# 3                 0       21.27      ZA  1729019151
# 6               100        3.00      NZ  1729019154
# 7                14       12.93      SH  1729019155
# 10              100       15.19      ZA  1729019158

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

plt.title("Latitude vs Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plot_linear_regression(x_values, y_values, "Latitude vs Max Temp", (6, 30))
# Out:
# The r-squared is: 0.7217335463255659

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

plt.title("Latitude vs Max Temp")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plot_linear_regression(x_values, y_values, "Latitude vs Max Temp", (-30, 20))
# Out:
# The r-squared is: 0.47927925279896405

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plot_linear_regression(x_values, y_values, "Latitude vs Humidity", (6, 30))
# Out:
# The r-squared is: 0.022855742910639576

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

plt.title("Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plot_linear_regression(x_values, y_values, "Latitude vs Humidity", (-30, 30))
# Out:
# The r-squared is: 0.0056114057233127715

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (6, 30))
# Out:
# The r-squared is: 0.00039877917470873157

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

plt.title("Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (-30, 10))
# Out:
# The r-squared is: 0.04158017003263378

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (4, 20))
# Out:
# The r-squared is: 0.007027170568597375

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

plt.title("Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plot_linear_regression(x_values, y_values, "Latitude vs Cloudiness", (-50, 20))
# Out:
# The r-squared is: 0.08118232147610643

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
